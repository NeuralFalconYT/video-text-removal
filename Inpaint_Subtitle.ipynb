# %%
import os
GITHUB_TOKEN=""  # @param {type: "string"}
REPO_URL = "https://github.com/NeuralFalconYT/video-text-removal.git"
# Use the token in the correct format
CLONE_URL = REPO_URL.replace("https://", f"https://{GITHUB_TOKEN}@")
# %cd /content/
# !rm -rf /content/video-text-removal
# !git clone {CLONE_URL}
# !pip install loguru
# !pip install rapidocr_onnxruntime
# !pip install onnxruntime
# !pip install onnxruntime-gpu
from IPython.display import clear_output
clear_output()

# %%
#@title Prevent Colab from Sleeping
from IPython.display import Audio,display
display(Audio("https://raw.githubusercontent.com/KoboldAI/KoboldAI-Client/main/colab/silence.m4a", autoplay=True))

# %%
#@title Mount Google Drive for auto save [ Optional, helpful for Auto Save]
# %cd /content/
from IPython.display import clear_output
from google.colab import drive
import os

auto_save_in_drive = True  # @param {type: "boolean"}

if auto_save_in_drive:
    drive.mount('/content/gdrive', force_remount=True)
    os.makedirs("/content/gdrive/MyDrive/subtitle_inpaint", exist_ok=True)
    clear_output()
    print("✅ A copy of Final Video will save at Google Drive.")

# %%
#@title Run App
# %cd /content/video-text-removal
# !python remove_subtitle.py --share --debug
